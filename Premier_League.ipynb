# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('stats.csv')

# %%
df.head()
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 0  Manchester United  28.0     5.0   83.0            60.0             1.0
# 1            Chelsea  24.0     3.0   64.0            62.0             4.0
# 2          Liverpool  20.0    10.0   57.0            44.0             0.0
# 3            Arsenal  19.0     8.0   63.0            59.0             3.0
# 4  Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
#
#    total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0              698.0                 256.0          21.0         12.0  ...
# 1              636.0                 216.0          14.0         16.0  ...
# 2              668.0                 214.0          15.0          8.0  ...
# 3              638.0                 226.0          19.0         10.0  ...
# 4              520.0                 184.0           6.0          5.0  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 42 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   team                  240 non-null    object
#  1   wins                  240 non-null    float64
#  2   losses                240 non-null    float64
#  3   goals                 240 non-null    float64
#  4   total_yel_card        240 non-null    float64
#  5   total_red_card        240 non-null    float64
#  6   total_scoring_att     240 non-null    float64
#  7   ontarget_scoring_att  240 non-null    float64
#  8   hit_woodwork          240 non-null    float64
#  9   att_hd_goal           240 non-null    float64
#  10  att_pen_goal          240 non-null    float64
#  11  att_freekick_goal     240 non-null    float64
#  12  att_ibox_goal         240 non-null    float64
#  13  att_obox_goal         240 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# team                     0
# wins                     0
# losses                   0
# goals                    0
# total_yel_card           0
# total_red_card           0
# total_scoring_att        0
# ontarget_scoring_att     0
# hit_woodwork             0
# att_hd_goal              0
# att_pen_goal             0
# att_freekick_goal        0
# att_ibox_goal            0
# att_obox_goal            0
# goal_fastbreak           0
# total_offside            0
# clean_sheet              0
# goals_conceded           0
# saves                   20
# outfielder_block         0
# interception             0
# total_tackle             0
# last_man_tackle          0
# total_clearance          0
# head_clearance          20
# own_goals                0
# penalty_conceded         0
# pen_goals_conceded       0
# total_pass               0
# total_through_ball      20
# total_long_balls         0
# backward_pass           80
# total_cross              0
# corner_taken             0
# ...

# %%
mean=df["big_chance_missed"].mean()

# %%
df['big_chance_missed'] = df['big_chance_missed'].fillna(mean)

# %%
mean1=df["backward_pass"].mean()

# %%
df['backward_pass'] = df['backward_pass'].fillna(mean1)

# %%
abs(df.corr()["wins"]).sort_values(ascending=False)
# Out:
# wins                    1.000000
# goals                   0.899236
# losses                  0.890199
# att_ibox_goal           0.869687
# ontarget_scoring_att    0.825577
# goals_conceded          0.808909
# clean_sheet             0.768052
# total_scoring_att       0.753944
# touches                 0.704645
# corner_taken            0.702131
# total_pass              0.701707
# att_obox_goal           0.580104
# outfielder_block        0.564550
# goal_fastbreak          0.519834
# hit_woodwork            0.512426
# backward_pass           0.506569
# big_chance_missed       0.491315
# total_through_ball      0.488155
# att_pen_goal            0.398314
# att_hd_goal             0.354752
# clearance_off_line      0.316998
# pen_goals_conceded      0.299222
# att_freekick_goal       0.296696
# penalty_conceded        0.293302
# dispossessed            0.260774
# own_goals               0.243475
# total_clearance         0.243472
# total_long_balls        0.228135
# ...

# %%
plt.subplots(figsize = (30,25))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df[["goals","losses","att_ibox_goal","ontarget_scoring_att","goals_conceded","clean_sheet","total_scoring_att","touches","corner_taken","total_pass","backward_pass","big_chance_missed","att_obox_goal","outfielder_block","goal_fastbreak","hit_woodwork"]]

# %%
y=df[["wins"]]

# %%
x.head()
# Out:
#    goals  losses  att_ibox_goal  ontarget_scoring_att  goals_conceded  \
# 0   83.0     5.0           72.0                 256.0            27.0
# 1   64.0     3.0           41.0                 216.0            24.0
# 2   57.0    10.0           46.0                 214.0            27.0
# 3   63.0     8.0           53.0                 226.0            35.0
# 4   57.0    12.0           44.0                 184.0            54.0
#
#    clean_sheet  total_scoring_att  touches  corner_taken  total_pass  \
# 0         16.0              698.0  25686.0         258.0     18723.0
# 1         22.0              636.0  24010.0         231.0     16759.0
# 2         20.0              668.0  24150.0         282.0     17154.0
# 3         12.0              638.0  25592.0         278.0     18458.0
# 4          6.0              520.0  22200.0         181.0     14914.0
#
#    backward_pass  big_chance_missed  att_obox_goal  outfielder_block  \
# ...

# %%
x.shape
# Out:
# (240, 16)

# %%
y.shape
# Out:
# (240, 1)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =train_test_split(x,y,test_size=0.2,random_state=13) 
print("Values in x_train",x_train)
print("Values in y_train",y_train)
# Out:
# Values in x_train      goals  losses  att_ibox_goal  ontarget_scoring_att  goals_conceded  \
# 9     45.0    12.0           32.0                 186.0            42.0
# 213   47.0    17.0           41.0                 138.0            64.0
# 33    43.0    16.0           37.0                 152.0            53.0
# 208   50.0    21.0           48.0                 138.0            63.0
# 155   41.0    20.0           37.0                 138.0            60.0
# ..     ...     ...            ...                   ...             ...
# 230   45.0    16.0           38.0                 158.0            61.0
# 16    37.0    20.0           31.0                 147.0            59.0
# 74    37.0    20.0           32.0                 174.0            79.0
# 176   33.0    19.0           30.0                 131.0            51.0
# 82    60.0     9.0           51.0                 177.0            33.0
#
#      clean_sheet  total_scoring_att  touches  corner_taken  total_pass  \
# ...

# %%
x_train.shape, x_test.shape,y_train.shape,y_test.shape
# Out:
# ((192, 16), (48, 16), (192, 1), (48, 1))

# %%
lr=LinearRegression()
regmodel=lr.fit(x_train,y_train)

# %%
y_pretest=lr.predict(x_test) 
y_pretest
# Out:
# array([[21.25882881],
#        [16.24636052],
#        [15.97145899],
#        [11.05682801],
#        [23.73730533],
#        [12.84889024],
#        [11.4021969 ],
#        [ 7.83437611],
#        [22.69144985],
#        [11.52390978],
#        [13.45708834],
#        [25.87244509],
#        [10.07568062],
#        [11.66773564],
#        [11.96183298],
#        [11.87027288],
#        [ 8.54426131],
#        [13.48863372],
#        [ 9.36512723],
#        [ 7.89456224],
#        [19.59820448],
#        [10.43501945],
#        [17.28689232],
#        [19.4902722 ],
#        [22.50983841],
#        [11.68001806],
#        [16.58320819],
#        [10.7687553 ],
#        [21.4832086 ],
#        [ 5.66947156],
#        [26.88690673],
#        [11.36160958],
#        [19.6318864 ],
#        [10.53895179],
#        [ 6.98686105],
#        [28.23941572],
#        [ 7.54972281],
#        [12.88475172],
#        [17.44776333],
#        [20.61927033],
#        [11.94664901],
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
(mean_squared_error(y_test,y_pretest))**0.5
# Out:
# 1.824729321174111

# %%
r2_score(y_test,y_pretest)
# Out:
# 0.9041531769743121

# %%
x.head()
# Out:
#    goals  losses  att_ibox_goal  ontarget_scoring_att  goals_conceded  \
# 0   83.0     5.0           72.0                 256.0            27.0
# 1   64.0     3.0           41.0                 216.0            24.0
# 2   57.0    10.0           46.0                 214.0            27.0
# 3   63.0     8.0           53.0                 226.0            35.0
# 4   57.0    12.0           44.0                 184.0            54.0
#
#    clean_sheet  total_scoring_att  touches  corner_taken  total_pass  \
# 0         16.0              698.0  25686.0         258.0     18723.0
# 1         22.0              636.0  24010.0         231.0     16759.0
# 2         20.0              668.0  24150.0         282.0     17154.0
# 3         12.0              638.0  25592.0         278.0     18458.0
# 4          6.0              520.0  22200.0         181.0     14914.0
#
#    backward_pass  big_chance_missed  att_obox_goal  outfielder_block  \
# ...

# %%
lr.predict([[50,10,40,260,40,20,650,23000,250,15000,3000,40,10,80,10,20]]) ### premier leauge'de bu verilere sahip bir takım bir sezon boyunca %90 doğruluk oranıyla 38 maçta 18.4 maçını kazanacak.
# Out:
# C:\Users\18040\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[18.41120956]])

# %% [markdown]
# **Data Scaling and Normalization**

# %%
from sklearn.preprocessing import scale,normalize

# %%
data = scale(x) # -1<x<1 arasına verileri ölçeklendirdik.

# %%
normal_data = normalize(x) # 0<x<1 arasına verileri normalize ettik.

# %%
sns.distplot(data)
# Out:
# C:\Users\18040\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(normal_data)
# Out:
# C:\Users\18040\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # **Deep Learning Models**

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))
model.compile(optimizer="Adam",loss="mse")

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=128,epochs=1500)
model.summary()
# Out:
# Epoch 1/1500
# 2/2 [==============================] - 1s 208ms/step - loss: 1553808.0000 - val_loss: 1194256.6250
# Epoch 2/1500
# 2/2 [==============================] - 0s 21ms/step - loss: 1052833.0000 - val_loss: 775833.8125
# Epoch 3/1500
# 2/2 [==============================] - 0s 21ms/step - loss: 679276.5625 - val_loss: 488360.2812
# Epoch 4/1500
# 2/2 [==============================] - 0s 20ms/step - loss: 425314.0000 - val_loss: 290564.5938
# Epoch 5/1500
# 2/2 [==============================] - 0s 19ms/step - loss: 250729.5781 - val_loss: 165978.9375
# Epoch 6/1500
# 2/2 [==============================] - 0s 19ms/step - loss: 142736.5156 - val_loss: 88718.9766
# Epoch 7/1500
# 2/2 [==============================] - 0s 19ms/step - loss: 75076.2266 - val_loss: 43856.1562
# Epoch 8/1500
# 2/2 [==============================] - 0s 20ms/step - loss: 37141.3320 - val_loss: 19414.9434
# Epoch 9/1500
# ...

# %%
loss_df=pd.DataFrame(model.history.history)

# %%
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
tahmin=model.predict(x)
# Out:
# 8/8 [==============================] - 0s 855us/step

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2_score(tahmin,y)
# Out:
# -0.25331378522180326

# %%
(mean_squared_error(tahmin,y))**0.5
# Out:
# 4.869395027972337

# %%
x.head()
# Out:
#    goals  losses  att_ibox_goal  ontarget_scoring_att  goals_conceded  \
# 0   83.0     5.0           72.0                 256.0            27.0
# 1   64.0     3.0           41.0                 216.0            24.0
# 2   57.0    10.0           46.0                 214.0            27.0
# 3   63.0     8.0           53.0                 226.0            35.0
# 4   57.0    12.0           44.0                 184.0            54.0
#
#    clean_sheet  total_scoring_att  touches  corner_taken  total_pass  \
# 0         16.0              698.0  25686.0         258.0     18723.0
# 1         22.0              636.0  24010.0         231.0     16759.0
# 2         20.0              668.0  24150.0         282.0     17154.0
# 3         12.0              638.0  25592.0         278.0     18458.0
# 4          6.0              520.0  22200.0         181.0     14914.0
#
#    backward_pass  big_chance_missed  att_obox_goal  outfielder_block  \
# ...

# %%
model.predict([[89,1,75,256,27,16,700,25700,270,18900,2450,40,14,82,9,20]])
# Out:
# 1/1 [==============================] - 0s 98ms/step
# array([[19.884932]], dtype=float32)
